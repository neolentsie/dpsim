# %% [markdown]
# # EMT Ph3 Linear Circuit SSN

# %% [markdown]
# ## Run C++ examples

# %%
import os
import subprocess

#%matplotlib widget

name = 'EMT_Ph1_Diode_test'

dpsim_path = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

path_exec = dpsim_path + '/build/dpsim/examples/cxx/'
sim = subprocess.Popen([path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(sim.communicate()[0].decode())
# Out:
# [14:11:23.592483 EMT_Ph1_Diode_test info] Initialize simulation: EMT_Ph1_Diode_test
# [14:11:23.592805 EMT_Ph1_Diode_test_Solver warning] Linear solver configuration is not used!
# [14:11:23.593172 EMT_Ph1_Diode_test_Solver warning] Linear solver configuration is not used!
# [14:11:23.593341 EMT_Ph1_Diode_test info] Scheduling tasks.
# [14:11:23.593520 EMT_Ph1_Diode_test info] Scheduling done.
# [14:11:23.593528 EMT_Ph1_Diode_test info] Opening interfaces.
# [14:11:23.593530 EMT_Ph1_Diode_test info] Start synchronization with remotes on interfaces
# [14:11:23.593531 EMT_Ph1_Diode_test info] Synchronized simulation start with remotes
# [14:11:23.593534 EMT_Ph1_Diode_test info] Start simulation: EMT_Ph1_Diode_test
# [14:11:23.593537 EMT_Ph1_Diode_test info] Time step: 1.000000e-04
# [14:11:23.593540 EMT_Ph1_Diode_test info] Final time: 1.000000e-01
# 30
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# [14:11:23.742114 EMT_Ph1_Diode_test info] Simulation calculation time: 0.148570
# [14:11:23.742144 EMT_Ph1_Diode_test info] Simulation finished.

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

work_dir = os.getcwd() + "/logs/"
path_logfile = work_dir + name + '/' + name + '.csv'
ts_dpsim_EMT = read_timeseries_dpsim(path_logfile)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Input In [2], in <module>
#       9 work_dir = os.getcwd() + "/logs/"
#      10 path_logfile = work_dir + name + '/' + name + '.csv'
# ---> 11 ts_dpsim_EMT = read_timeseries_dpsim(path_logfile)
#
# File ~/.local/lib/python3.9/site-packages/villas/dataprocessing/readtools.py:130, in read_timeseries_dpsim(filename, timeseries_names, print_status)
#     129 def read_timeseries_dpsim(filename, timeseries_names=None, print_status=True):
# --> 130     return read_timeseries_csv(filename, timeseries_names, print_status)
#
# File ~/.local/lib/python3.9/site-packages/villas/dataprocessing/readtools.py:69, in read_timeseries_csv(filename, timeseries_names, print_status)
#      62 def read_timeseries_csv(filename, timeseries_names=None, print_status=True):
#      63     """Reads complex time series data from DPsim log file. Real and
#      64     imaginary part are stored in one complex variable.
#      65     :param filename: name of the csv file that has the data
#      66     :param timeseries_names: column name which should be read
#      67     :return: list of Timeseries objects
#      68     """
# ---> 69     pd_df = pd.read_csv(filename)
#      70     timeseries_list = {}
#      71     cmpl_result_columns = []
#
# File ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:551, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# ### Load Results

# %%
plt.close('all')
fig1 = plt.figure()

plt.plot(ts_dpsim_EMT['V_Diode'].time, ts_dpsim_EMT['V_Diode'].values, "r-", label='V_D')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Diode Voltage')
plt.xlabel('t [s]')
plt.ylabel('Voltage [V]')

fig2 = plt.figure()

plt.plot(ts_dpsim_EMT['I_Diode'].time, ts_dpsim_EMT['I_Diode'].values, "r-", label='I_D')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Diode Current')
plt.xlabel('t [s]')
plt.ylabel('Current [A]')
