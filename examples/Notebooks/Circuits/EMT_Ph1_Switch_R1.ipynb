# %%
import os
import subprocess

# %matplotlib widget

name = 'EMT_Ph1_Switch_R1'

dpsim_path = subprocess.Popen(['git', 'rev-parse', '--show-toplevel'], stdout=subprocess.PIPE).communicate()[0].rstrip().decode('utf-8')

path_exec = dpsim_path + '/build/dpsim/examples/cxx/'
sim = subprocess.Popen([path_exec + name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(sim.communicate()[0].decode())
# Out:
# [17:47:17.631163 EMT_Ph1_SwitchTest info] Initialize simulation: EMT_Ph1_SwitchTest
# [17:47:17.631288 MnaSolverFactory info] creating EigenSparse solver implementation
# [17:47:17.631943 EMT_Ph1_SwitchTest info] Scheduling tasks.
# [17:47:17.632117 EMT_Ph1_SwitchTest info] Scheduling done.
# [17:47:17.632128 EMT_Ph1_SwitchTest info] Opening interfaces.
# [17:47:17.632130 EMT_Ph1_SwitchTest info] Start synchronization with remotes on interfaces
# [17:47:17.632131 EMT_Ph1_SwitchTest info] Synchronized simulation start with remotes
# [17:47:17.632133 EMT_Ph1_SwitchTest info] Start simulation: EMT_Ph1_SwitchTest
# [17:47:17.632136 EMT_Ph1_SwitchTest info] Time step: 1.000000e-03
# [17:47:17.632139 EMT_Ph1_SwitchTest info] Final time: 1.000000e-01
# 6.000000e-02: Handle event time
# [17:47:17.634483 EMT_Ph1_SwitchTest info] Simulation calculation time: 0.002339
# [17:47:17.634531 EMT_Ph1_SwitchTest info] Simulation finished.

# %%
from villas.dataprocessing.readtools import *
from villas.dataprocessing.timeseries import *
from villas.dataprocessing.timeseries import TimeSeries as ts
import matplotlib.pyplot as plt
import re
import numpy as np
import math

import os

result_name = 'EMT_Ph1_SwitchTest'

work_dir = os.getcwd() + "/logs/"

path_logfile = work_dir + result_name + ".csv"
ts_dpsim_EMT = read_timeseries_dpsim(path_logfile)
# Out:
# column number: 1
# results length: 100
# real column names: ['I']
# complex column names: []

# %%
plt.close('all')
fig1 = plt.figure()

plt.plot(ts_dpsim_EMT['I'].time, ts_dpsim_EMT['I'].values, "r-", label='I')

plt.legend(loc = 4)
#plt.legend(bbox_to_anchor=(1,1))

plt.title('Resistor Current')
plt.xlabel('t [s]')
plt.ylabel('Current [A]')
# Out:
# Text(0, 0.5, 'Current [A]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
